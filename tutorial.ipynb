# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/inspektral/tutorial/blob/main/tutorial.ipynb)

# %%
import utils

# %%
utils.sum([1,2,3])
# Out:
# 6
